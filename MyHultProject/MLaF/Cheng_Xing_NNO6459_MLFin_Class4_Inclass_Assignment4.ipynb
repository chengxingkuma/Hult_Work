# %% [markdown]
# # Machine Learning Application in Finance
# # &emsp; NNO6459-BNNO1, Spring 2021
#
# ### &emsp; &emsp; Professor: Philip Sun
# ### &emsp; &emsp; Email: philip.sun@faculty.hult.edu
# ### &emsp; &emsp; Last Modified: 3/18/2021
#
# ___
#
# ## Class 4: Other ML Applications in Finance, ESG/DEIB Discussion and Course Conclusion
#
# ## &emsp; In-Class Assignment (Graded): Principal Component Analysis

# %%
#pip install mglearn # we should install this first or it will show error when import on python
# if you instal it please add # before code.

# %%
# import modules
import math
import numpy as np
import pandas as pd
import yfinance as yf #you should have this installed from Class 1.
import datetime as dt
import mglearn
import matplotlib as plt

# %%
# Generate Plot for the class slides
mglearn.plots.plot_pca_illustration()  # "Introduction to Machine Learning with Python" by Muller and Guido

# %%
# Read the Federal Reserve Constant Maturity Dataset
# Please download 'FRB_H15.csv' from my course page and save in the same directory as the python notebook

csv_file='FRB_H15.csv'
df_cmt=pd.read_csv(csv_file, index_col=None)
df_cmt
# Out:
#      Time Period   CM03   CM06   CY01   CY02   CY03   CY05   CY07   CY10  \
# 0       9/1/1981  17.01  17.17  17.06  16.78  16.57  16.12  15.71  15.41
# 1       9/2/1981  16.65  17.32  17.16  16.78  16.43  16.09  15.75  15.40
# 2       9/3/1981  16.96  17.42  17.31  16.90  16.48  16.14  15.78  15.48
# 3       9/4/1981  16.64  17.37  17.24  16.89  16.52  16.17  15.86  15.51
# 4       9/8/1981  16.54  17.43  17.29  16.95  16.56  16.23  15.92  15.59
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 9878   3/10/2021   0.04   0.06   0.08   0.16   0.32   0.80   1.20   1.53
# 9879   3/11/2021   0.04   0.05   0.08   0.14   0.31   0.78   1.20   1.54
# 9880   3/12/2021   0.04   0.06   0.09   0.14   0.34   0.85   1.30   1.64
# 9881   3/15/2021   0.04   0.06   0.08   0.14   0.33   0.84   1.28   1.62
# 9882   3/16/2021   0.02   0.06   0.07   0.15   0.33   0.83   1.28   1.62
#
#        CY20   CY30
# 0     15.09  14.70
# 1     15.11  14.70
# 2     15.21  14.82
# 3     15.24  14.84
# 4     15.36  14.99
# ...     ...    ...
# 9878   2.15   2.24
# 9879   2.18   2.29
# 9880   2.31   2.40
# 9881   2.27   2.37
# 9882   2.30   2.38
#
# [9883 rows x 11 columns]

# %%
# Here I am just doing some transformation for Time Period column, before using time as index.

df_cmt['Time Period']=df_cmt['Time Period'].apply(pd.to_datetime)
df_cmt.set_index('Time Period',inplace=True, drop=True)
df_cmt
# Out:
#               CM03   CM06   CY01   CY02   CY03   CY05   CY07   CY10   CY20  \
# Time Period
# 1981-09-01   17.01  17.17  17.06  16.78  16.57  16.12  15.71  15.41  15.09
# 1981-09-02   16.65  17.32  17.16  16.78  16.43  16.09  15.75  15.40  15.11
# 1981-09-03   16.96  17.42  17.31  16.90  16.48  16.14  15.78  15.48  15.21
# 1981-09-04   16.64  17.37  17.24  16.89  16.52  16.17  15.86  15.51  15.24
# 1981-09-08   16.54  17.43  17.29  16.95  16.56  16.23  15.92  15.59  15.36
# ...            ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2021-03-10    0.04   0.06   0.08   0.16   0.32   0.80   1.20   1.53   2.15
# 2021-03-11    0.04   0.05   0.08   0.14   0.31   0.78   1.20   1.54   2.18
# 2021-03-12    0.04   0.06   0.09   0.14   0.34   0.85   1.30   1.64   2.31
# 2021-03-15    0.04   0.06   0.08   0.14   0.33   0.84   1.28   1.62   2.27
# 2021-03-16    0.02   0.06   0.07   0.15   0.33   0.83   1.28   1.62   2.30
#
#               CY30
# Time Period
# 1981-09-01   14.70
# 1981-09-02   14.70
# 1981-09-03   14.82
# 1981-09-04   14.84
# 1981-09-08   14.99
# ...            ...
# 2021-03-10    2.24
# 2021-03-11    2.29
# 2021-03-12    2.40
# 2021-03-15    2.37
# 2021-03-16    2.38
#
# [9883 rows x 10 columns]

# %%
# now we run principal components analysis on the yields
# First let's normalize the yields
#from sklearn import preprocessing
#scaler = preprocessing.StandardScaler().fit(df_cmt)
#cmt_scaled = scaler.transform(df_cmt)

from sklearn.decomposition import PCA

#  Follow the professor fill in blank ________ below ( not fill this ! )

# keep the first 3 principal components
pca = PCA(n_components= 3)

# fit PCA model to breast cancer data
pca.fit(df_cmt)

# transform, i.e. rotate yield onto the first 3 principal components
yc_pca = pca.transform(df_cmt)

print("yield data shape: {}".format(str(df_cmt.shape)))
print("pca transformed yc shape: {}".format(str(yc_pca.shape)))
# Out:
# yield data shape: (9883, 10)
# pca transformed yc shape: (9883, 3)

# %%
pd.DataFrame(yc_pca, columns=['PC1','PC2','PC3'], index=df_cmt.index)
# Out:
#                    PC1       PC2       PC3
# Time Period
# 1981-09-01   35.577048  3.425377 -1.148484
# 1981-09-02   35.504961  3.346683 -1.066946
# 1981-09-03   35.852849  3.458134 -1.236878
# 1981-09-04   35.782756  3.228510 -1.044536
# 1981-09-08   35.960158  3.078062 -1.033878
# ...                ...       ...       ...
# 2021-03-10  -13.001269  0.455579 -0.049256
# 2021-03-11  -12.995980  0.412804 -0.092577
# 2021-03-12  -12.826801  0.257612 -0.125839
# 2021-03-15  -12.868871  0.295260 -0.113175
# 2021-03-16  -12.866951  0.270049 -0.116024
#
# [9883 rows x 3 columns]

# %%
df_pcacomponents=pd.DataFrame(pca.components_, index=['Level','Slope','Curvature'], columns=df_cmt.columns)
df_pcacomponents
# Out:
#                CM03      CM06      CY01      CY02      CY03      CY05  \
# Level      0.310493  0.323157  0.331148  0.341509  0.338883  0.327883
# Slope      0.422518  0.396790  0.325188  0.172231  0.059599 -0.124276
# Curvature -0.509408 -0.256614  0.042914  0.354211  0.422565  0.323936
#
#                CY07      CY10      CY20      CY30
# Level      0.317963  0.304944  0.285666  0.273554
# Slope     -0.228752 -0.319269 -0.402590 -0.439647
# Curvature  0.175659 -0.033421 -0.306580 -0.371330

# %%
# Plot
import matplotlib.pyplot as plt
# %matplotlib inline 

#plt.figure(figsize=(10,7))
numsub=len(df_pcacomponents.index)
fig, axs = plt.subplots(numsub, sharex=True, sharey=True)
fig.suptitle('PCA Components (Coefficients)')
fig.set_figheight(3*numsub)
fig.set_figwidth(15)

for i in range(numsub):
    axs[i].bar(df_pcacomponents.columns, df_pcacomponents.iloc[i,:])
    axs[i].title.set_text(df_pcacomponents.index[i])
plt.xlabel('Yied Curve Maturity Points')
# Out:
# Text(0.5, 0, 'Yied Curve Maturity Points')

# %%
# Plot
import matplotlib.pyplot as plt
# %matplotlib inline 

plt.figure(figsize=(15,10))

plt.plot(pd.DataFrame(yc_pca, columns=['PC1','PC2','PC3'], index=df_cmt.index))
#plt.plot(datetra, p_tree_insample)
#plt.plot(dateval, p_tree_prediction)
#plt.plot(datetra, p_lr_insample)
#plt.plot(dateval, p_lr_prediction)

plt.title('PCA Value')
plt.xlabel('Date')
plt.ylabel('PCA Value')
plt.legend(['PC1','PC2','PC3'])
